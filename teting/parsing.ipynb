# %%
import csv
import pandas as pd
import os
from pathlib import Path
import datetime

# %%
def iso_to_unix(iso_str):
    # Handles ISO 8601 with 'Z' (UTC)
    # 2025-06-29T08:08:20Z
    try:
        dt = datetime.datetime.strptime(iso_str, "%Y-%m-%dT%H:%M:%SZ")
        dt = dt.replace(tzinfo=datetime.timezone.utc)
        return int(dt.timestamp())
    except ValueError as e:
        print(f"erro: {iso_str}")
        raise e

# %%
def parse_csv(file_path):
    csv_file = []
    idx = 0
    with open(file_path, mode='r', newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            if (idx == 0):
                idx+=1
                continue
            row[0] = iso_to_unix(row[0])
            row[1] = float(row[1])
            csv_file.append(row)
    return csv_file

# %%
files = {}
data_dir = Path(Path.cwd().parent / "La Vista 1H")
for file_name in os.listdir(data_dir):
    content = parse_csv(
        data_dir / file_name
    )
    files[file_name] = content

# %%
files["Sales Meter Flow Rate (MCF_Day).csv"][1]
# Out:
# [1751184620, 567.95]

# %% [markdown]
# ## cleaning up logic
# cleaning the data before 1st proper start cycle

# %%
for file in files:
    print(file)
# Out:
# Sales Meter Static Pressure (PSIA).csv
# Line Pressure (PSIA).csv
# Casing Pressure (PSI).csv
# Tubing Pressure (PSI).csv
# Arrival Time Remaining.csv
# Sales Meter Flow Rate (MCF_Day).csv
# Arrival Speed.csv
# Current Non-Arrival Count.csv
# Down Hole Pressure (PSI).csv

# %%
files["Sales Meter Flow Rate (MCF_Day).csv"]
# Out:
# [[1751184500, 585.2],
#  [1751184620, 567.95],
#  [1751184740, 0.0],
#  [1751184860, 0.0],
#  [1751184980, 0.0],
#  [1751185100, 1054.75],
#  [1751185220, 650.64],
#  [1751185340, 613.71],
#  [1751185460, 542.38],
#  [1751185580, 611.62],
#  [1751185700, 573.69],
#  [1751185820, 517.6],
#  [1751185940, 0.0],
#  [1751186060, 0.0],
#  [1751186180, 0.0],
#  [1751186300, 0.0],
#  [1751186420, 617.83],
#  [1751186540, 515.95],
#  [1751186660, 476.27],
#  [1751186780, 411.39],
#  [1751186900, 688.06],
#  [1751187020, 595.41],
#  [1751187140, 580.13],
#  [1751187260, 0.0],
#  [1751187380, 0.0],
#  [1751187500, 0.0],
#  [1751187620, 0.0],
#  [1751187740, 709.58],
#  [1751187860, 587.85],
#  [1751187980, 542.48],
#  [1751188100, 437.1],
#  [1751188220, 604.91],
#  [1751188340, 568.88],
#  [1751188460, 50.51],
#  [1751188580, 0.0],
#  [1751188700, 0.0],
#  [1751188820, 0.0],
#  [1751188940, 732.92],
#  [1751189060, 544.09],
#  [1751189180, 520.34],
#  [1751189300, 471.18],
#  [1751189420, 403.82],
#  [1751189540, 658.41],
#  [1751189660, 584.66],
#  [1751189780, 49.72],
#  [1751189900, 0.0],
#  [1751190020, 0.0],
#  [1751190140, 0.0],
#  [1751190260, 697.57],
#  [1751190380, 616.57],
#  [1751190500, 557.48],
#  [1751190620, 540.8],
#  [1751190740, 480.84],
#  [1751190860, 392.52],
#  [1751190980, 287.06],
#  [1751191100, 647.92],
#  [1751297540, 832.11],
#  [1751297660, 734.84],
#  [1751297780, 529.5],
#  [1751297900, 490.88],
#  [1751298020, 426.9],
#  [1751298140, 345.68],
#  [1751298260, 630.88],
#  [1751298380, 614.3],
#  [1751298500, 0.0],
#  [1751298620, 0.0],
#  [1751298740, 0.0],
#  [1751298860, 0.0],
#  [1751298980, 991.11],
#  [1751299100, 649.18],
#  [1751299220, 620.4],
#  [1751299340, 512.11],
#  [1751299460, 594.28],
#  [1751299580, 585.19],
#  [1751299700, 278.26],
#  [1751299820, 0.0],
#  [1751299940, 0.0],
#  [1751300060, 0.0],
#  [1751300180, 691.56],
#  [1751300300, 558.82],
#  [1751300420, 535.35],
#  [1751300540, 495.95],
#  [1751300660, 619.37],
#  [1751300780, 580.55],
#  [1751300900, 566.07],
#  [1751301020, 0.0],
#  [1751301140, 0.0],
#  [1751301260, 0.0],
#  [1751301380, 970.43],
#  [1751301500, 704.91],
#  [1751301620, 574.34],
#  [1751301740, 525.57],
#  [1751301860, 415.2],
#  [1751301980, 579.09],
#  [1751302100, 541.24],
#  [1751302220, 0.0],
#  [1751302340, 0.0],
#  [1751302460, 0.0],
#  [1751302580, 0.0],
#  [1751302700, 959.29],
#  [1751302820, 615.67],
#  [1751302940, 561.27],
#  [1751303060, 511.55],
#  [1751303180, 440.77],
#  [1751303300, 640.43],
#  [1751303420, 600.43],
#  [1751303540, 569.64],
#  [1751303660, 0.0],
#  [1751303780, 0.0],
#  [1751303900, 0.0],
#  [1751304020, 844.98],
#  [1751304140, 585.34],
#  [1751304260, 541.69],
#  [1751304380, 514.56],
#  [1751304500, 396.83],
#  ...]

# %%
files["Sales Meter Flow Rate (MCF_Day).csv"][1][0] + 60
# Out:
# 1751184680

# %%
def cleanup():
    isotime_threshold = 0
    for i in range(len(files["Sales Meter Flow Rate (MCF_Day).csv"])):
        if files["Sales Meter Flow Rate (MCF_Day).csv"][i][1] == 0.0:
            if i==0: # if list is already clean (starting from zero)
                break
            isotime_threshold = files["Sales Meter Flow Rate (MCF_Day).csv"][i-1][0] + 60 # added one minute of threshold
            files["Sales Meter Flow Rate (MCF_Day).csv"] = files["Sales Meter Flow Rate (MCF_Day).csv"][i:]
            break
    # now cleaning all the data using this in all files
    for file in files:
        if(file=="Sales Meter Flow Rate (MCF_Day).csv"):
            continue
        for i in range(len(files[file])):
            if files[file][i][0] >= isotime_threshold:
                #print(f"threshold: ${isotime_threshold} and data: ${files[file][i][0]}\n")
                files[file] = files[file][i:]  # remove the first element
                break

cleanup()

# %% [markdown]
# ## Separate Out cycles

# %%
def flow_rate_cycles():
    flow_rate = files['Sales Meter Flow Rate (MCF_Day).csv']
    data = [[None, None, None] for i in range(len(flow_rate))]
    cycle_id = -1
    new_cycle_mil_gia = False
    for i in range(len(data)):
        if flow_rate[i][1] == 0.0 and not new_cycle_mil_gia:
            cycle_id+=1
            new_cycle_mil_gia = True
        elif flow_rate[i][1] > 0.0:
            new_cycle_mil_gia = False
        data[i][0] = cycle_id
        data[i][1] = flow_rate[i][0]
        data[i][2] = flow_rate[i][1]

    return data

# %%
files['Sales Meter Flow Rate (MCF_Day).csv'] = flow_rate_cycles()
files['Sales Meter Flow Rate (MCF_Day).csv']
# Out:
# [[0, 1751184740, 0.0],
#  [0, 1751184860, 0.0],
#  [0, 1751184980, 0.0],
#  [0, 1751185100, 1054.75],
#  [0, 1751185220, 650.64],
#  [0, 1751185340, 613.71],
#  [0, 1751185460, 542.38],
#  [0, 1751185580, 611.62],
#  [0, 1751185700, 573.69],
#  [0, 1751185820, 517.6],
#  [1, 1751185940, 0.0],
#  [1, 1751186060, 0.0],
#  [1, 1751186180, 0.0],
#  [1, 1751186300, 0.0],
#  [1, 1751186420, 617.83],
#  [1, 1751186540, 515.95],
#  [1, 1751186660, 476.27],
#  [1, 1751186780, 411.39],
#  [1, 1751186900, 688.06],
#  [1, 1751187020, 595.41],
#  [1, 1751187140, 580.13],
#  [2, 1751187260, 0.0],
#  [2, 1751187380, 0.0],
#  [2, 1751187500, 0.0],
#  [2, 1751187620, 0.0],
#  [2, 1751187740, 709.58],
#  [2, 1751187860, 587.85],
#  [2, 1751187980, 542.48],
#  [2, 1751188100, 437.1],
#  [2, 1751188220, 604.91],
#  [2, 1751188340, 568.88],
#  [2, 1751188460, 50.51],
#  [3, 1751188580, 0.0],
#  [3, 1751188700, 0.0],
#  [3, 1751188820, 0.0],
#  [3, 1751188940, 732.92],
#  [3, 1751189060, 544.09],
#  [3, 1751189180, 520.34],
#  [3, 1751189300, 471.18],
#  [3, 1751189420, 403.82],
#  [3, 1751189540, 658.41],
#  [3, 1751189660, 584.66],
#  [3, 1751189780, 49.72],
#  [4, 1751189900, 0.0],
#  [4, 1751190020, 0.0],
#  [4, 1751190140, 0.0],
#  [4, 1751190260, 697.57],
#  [4, 1751190380, 616.57],
#  [4, 1751190500, 557.48],
#  [4, 1751190620, 540.8],
#  [4, 1751190740, 480.84],
#  [4, 1751190860, 392.52],
#  [4, 1751190980, 287.06],
#  [4, 1751191100, 647.92],
#  [4, 1751191220, 613.04],
#  [4, 1751191340, 577.27],
#  [5, 1751191460, 0.0],
#  [5, 1751191580, 0.0],
#  [5, 1751191700, 0.0],
#  [5, 1751191820, 997.92],
#  [5, 1751191940, 607.46],
#  [5, 1751192060, 558.43],
#  [5, 1751192180, 500.3],
#  [5, 1751192300, 429.06],
#  [5, 1751192420, 646.92],
#  [5, 1751192540, 592.31],
#  [5, 1751192660, 552.46],
#  [6, 1751192780, 0.0],
#  [6, 1751192900, 0.0],
#  [6, 1751193020, 0.0],
#  [6, 1751193140, 0.0],
#  [6, 1751193260, 650.66],
#  [6, 1751193380, 550.51],
#  [6, 1751193500, 494.7],
#  [6, 1751193620, 636.61],
#  [6, 1751193740, 597.43],
#  [6, 1751193860, 591.48],
#  [7, 1751193980, 0.0],
#  [7, 1751194100, 0.0],
#  [7, 1751194220, 0.0],
#  [7, 1751194340, 0.0],
#  [7, 1751194460, 715.97],
#  [7, 1751194580, 622.59],
#  [7, 1751194700, 588.91],
#  [7, 1751194820, 622.06],
#  [24, 1751216780, 609.65],
#  [24, 1751216900, 570.06],
#  [24, 1751217020, 559.37],
#  [25, 1751217140, 0.0],
#  [25, 1751217260, 0.0],
#  [25, 1751217380, 0.0],
#  [25, 1751217500, 0.0],
#  [25, 1751217620, 647.06],
#  [25, 1751217740, 540.77],
#  [25, 1751217860, 514.94],
#  [25, 1751217980, 469.09],
#  [25, 1751218100, 348.81],
#  [25, 1751218220, 590.65],
#  [25, 1751218340, 552.33],
#  [26, 1751218460, 0.0],
#  [26, 1751218580, 0.0],
#  [26, 1751218700, 0.0],
#  [26, 1751218820, 0.0],
#  [26, 1751218940, 896.01],
#  [26, 1751219060, 563.01],
#  [26, 1751219180, 511.91],
#  [26, 1751219300, 445.18],
#  [26, 1751219420, 347.34],
#  [26, 1751219540, 632.28],
#  [26, 1751219660, 603.36],
#  [27, 1751219780, 0.0],
#  [27, 1751219900, 0.0],
#  [27, 1751220020, 0.0],
#  [27, 1751220140, 0.0],
#  [27, 1751220260, 909.77],
#  [27, 1751220380, 620.37],
#  [27, 1751220500, 577.79],
#  [27, 1751220620, 450.23],
#  [27, 1751220740, 592.17],
#  [27, 1751220860, 554.4],
#  [27, 1751220980, 501.82],
#  [28, 1751221100, 0.0],
#  [28, 1751221220, 0.0],
#  [28, 1751221340, 0.0],
#  [28, 1751221460, 896.21],
#  [28, 1751221580, 537.94],
#  [28, 1751221700, 458.82],
#  [28, 1751221820, 436.3],
#  [28, 1751221940, 345.66],
#  [28, 1751222060, 705.59],
#  [28, 1751222180, 610.67],
#  [28, 1751222300, 601.73],
#  [29, 1751222420, 0.0],
#  [29, 1751222540, 0.0],
#  [29, 1751222660, 0.0],
#  [29, 1751222780, 0.0],
#  [29, 1751222900, 737.44],
#  [29, 1751223020, 622.71],
#  [29, 1751223140, 580.69],
#  [29, 1751223260, 603.16],
#  [29, 1751223380, 590.84],
#  [29, 1751223500, 548.04],
#  [30, 1751223620, 0.0],
#  [30, 1751223740, 0.0],
#  [30, 1751223860, 0.0],
#  [30, 1751223980, 0.0],
#  [30, 1751224100, 736.01],
#  [30, 1751224220, 572.24],
#  [30, 1751224340, 520.09],
#  [30, 1751224460, 462.05],
#  [30, 1751224580, 565.88],
#  [30, 1751224700, 594.84],
#  [30, 1751224820, 544.91],
#  [31, 1751224940, 0.0],
#  [31, 1751225060, 0.0],
#  [31, 1751225180, 0.0],
#  [31, 1751225300, 0.0],
#  [31, 1751225420, 731.82],
#  [31, 1751225540, 535.87],
#  [31, 1751225660, 503.88],
#  [31, 1751225780, 408.34],
#  [31, 1751225900, 288.26],
#  [31, 1751226020, 613.77],
#  [31, 1751226140, 575.96],
#  [32, 1751226260, 0.0],
#  [32, 1751226380, 0.0],
#  [32, 1751226500, 0.0],
#  [32, 1751226620, 0.0],
#  [32, 1751226740, 781.4],
#  [32, 1751226860, 589.34],
#  [32, 1751226980, 541.39],
#  [32, 1751227100, 458.59],
#  [32, 1751227220, 588.11],
#  [32, 1751227340, 525.5],
#  [32, 1751227460, 509.12],
#  [33, 1751227580, 0.0],
#  [33, 1751227700, 0.0],
#  [33, 1751227820, 0.0],
#  [33, 1751227940, 0.0],
#  [33, 1751228060, 593.33],
#  [33, 1751228180, 504.89],
#  [33, 1751228300, 479.21],
#  [33, 1751228420, 418.81],
#  [33, 1751228540, 366.64],
#  [33, 1751228660, 669.56],
#  [33, 1751228780, 618.19],
#  [34, 1751228900, 0.0],
#  [34, 1751229020, 0.0],
#  [34, 1751229140, 0.0],
#  [34, 1751229260, 0.0],
#  [34, 1751229380, 752.95],
#  [34, 1751229500, 642.73],
#  [34, 1751229620, 563.04],
#  [34, 1751229740, 479.18],
#  [34, 1751229860, 596.46],
#  [34, 1751229980, 582.69],
#  [35, 1751230100, 0.0],
#  [35, 1751230220, 0.0],
#  [35, 1751230340, 0.0],
#  [35, 1751230460, 0.0],
#  [35, 1751230580, 1023.25],
#  [35, 1751230700, 622.05],
#  [35, 1751230820, 563.03],
#  [35, 1751230940, 503.28],
#  [35, 1751231060, 611.61],
#  [35, 1751231180, 587.92],
#  [35, 1751231300, 574.05],
#  [35, 1751231420, 39.61],
#  [36, 1751231540, 0.0],
#  [36, 1751231660, 0.0],
#  [36, 1751231780, 0.0],
#  [36, 1751231900, 675.93],
#  [36, 1751232020, 542.6],
#  [36, 1751232140, 504.0],
#  [36, 1751232260, 422.82],
#  [36, 1751232380, 372.7],
#  [36, 1751232500, 584.95],
#  [36, 1751232620, 582.3],
#  [36, 1751232740, 38.43],
#  [37, 1751232860, 0.0],
#  [37, 1751232980, 0.0],
#  [37, 1751233100, 848.51],
#  [37, 1751233220, 614.72],
#  [37, 1751233340, 570.23],
#  [37, 1751233460, 534.03],
#  [37, 1751233580, 454.24],
#  [37, 1751233700, 633.17],
#  [37, 1751233820, 572.38],
#  [38, 1751233940, 0.0],
#  [38, 1751234060, 0.0],
#  [38, 1751234180, 0.0],
#  [38, 1751234300, 0.0],
#  [38, 1751234420, 827.81],
#  [38, 1751234540, 556.17],
#  [38, 1751234660, 496.92],
#  [38, 1751234780, 446.72],
#  [38, 1751234900, 347.31],
#  [38, 1751235020, 612.76],
#  [38, 1751235140, 585.24],
#  [38, 1751235260, 569.96],
#  [39, 1751235380, 0.0],
#  [39, 1751235500, 0.0],
#  [39, 1751235620, 0.0],
#  [39, 1751235740, 861.51],
#  [39, 1751235860, 598.14],
#  [39, 1751235980, 542.98],
#  [39, 1751236100, 459.01],
#  [39, 1751236220, 409.68],
#  [39, 1751236340, 559.07],
#  [39, 1751236460, 551.97],
#  [40, 1751236580, 0.0],
#  [40, 1751236700, 0.0],
#  [40, 1751236820, 0.0],
#  [40, 1751236940, 0.0],
#  [40, 1751237060, 668.35],
#  [40, 1751237180, 592.03],
#  [40, 1751237300, 538.67],
#  [40, 1751237420, 488.27],
#  [40, 1751237540, 627.13],
#  [40, 1751237660, 560.01],
#  [40, 1751237780, 545.9],
#  [41, 1751237900, 0.0],
#  [41, 1751238020, 0.0],
#  [41, 1751238140, 0.0],
#  [41, 1751238260, 883.11],
#  [41, 1751238380, 553.51],
#  [41, 1751238500, 487.78],
#  [41, 1751238620, 434.9],
#  [41, 1751238740, 350.81],
#  [41, 1751238860, 628.49],
#  [41, 1751238980, 566.66],
#  [41, 1751239100, 561.17],
#  [42, 1751239220, 0.0],
#  [42, 1751239340, 0.0],
#  [42, 1751239460, 0.0],
#  [42, 1751239580, 926.4],
#  [42, 1751239700, 591.56],
#  [42, 1751239820, 547.04],
#  [42, 1751239940, 470.37],
#  [42, 1751240060, 400.21],
#  [42, 1751240180, 618.8],
#  [42, 1751240300, 572.09],
#  [43, 1751240420, 0.0],
#  [43, 1751240540, 0.0],
#  [43, 1751240660, 0.0],
#  [43, 1751240780, 0.0],
#  [43, 1751240900, 730.44],
#  [43, 1751241020, 610.45],
#  [43, 1751241140, 543.14],
#  [43, 1751241260, 479.87],
#  [43, 1751241380, 587.44],
#  [43, 1751241500, 579.64],
#  [43, 1751241620, 562.27],
#  [44, 1751241740, 0.0],
#  [44, 1751241860, 0.0],
#  [44, 1751241980, 0.0],
#  [44, 1751242100, 1031.17],
#  [44, 1751242220, 616.55],
#  [44, 1751242340, 546.01],
#  [44, 1751242460, 490.15],
#  [44, 1751242580, 630.53],
#  [44, 1751242700, 580.42],
#  [44, 1751242820, 562.77],
#  [45, 1751242940, 0.0],
#  [45, 1751243060, 0.0],
#  [45, 1751243180, 0.0],
#  [45, 1751243300, 0.0],
#  [45, 1751243420, 682.12],
#  [45, 1751243540, 542.88],
#  [45, 1751243660, 500.73],
#  [45, 1751243780, 427.67],
#  [45, 1751243900, 384.07],
#  [45, 1751244020, 638.67],
#  [45, 1751244140, 573.24],
#  [46, 1751244260, 0.0],
#  [46, 1751244380, 0.0],
#  [46, 1751244500, 0.0],
#  [46, 1751244620, 0.0],
#  [46, 1751244740, 739.33],
#  [46, 1751244860, 626.18],
#  [46, 1751244980, 549.66],
#  [46, 1751245100, 480.25],
#  [46, 1751245220, 582.32],
#  [46, 1751245340, 559.01],
#  [46, 1751245460, 544.34],
#  [47, 1751245580, 0.0],
#  [47, 1751245700, 0.0],
#  [47, 1751245820, 0.0],
#  [47, 1751245940, 456.73],
#  [47, 1751246060, 593.19],
#  [47, 1751246180, 548.54],
#  [47, 1751246300, 541.71],
#  [47, 1751246420, 531.96],
#  [47, 1751246540, 463.01],
#  [47, 1751246660, 360.41],
#  [47, 1751246780, 325.85],
#  [47, 1751246900, 603.49],
#  [47, 1751247020, 525.11],
#  [48, 1751247140, 0.0],
#  [48, 1751247260, 0.0],
#  [48, 1751247380, 0.0],
#  [48, 1751247500, 0.0],
#  [48, 1751247620, 724.13],
#  [48, 1751247740, 598.31],
#  [48, 1751247860, 516.31],
#  [48, 1751247980, 463.78],
#  [48, 1751248100, 390.81],
#  [48, 1751248220, 647.49],
#  [48, 1751248340, 587.93],
#  [48, 1751248460, 35.5],
#  [49, 1751248580, 0.0],
#  [49, 1751248700, 0.0],
#  [49, 1751248820, 0.0],
#  [49, 1751248940, 971.14],
#  [49, 1751249060, 612.27],
#  [49, 1751249180, 519.65],
#  [49, 1751249300, 463.07],
#  [49, 1751249420, 358.26],
#  [49, 1751249540, 623.42],
#  [58, 1751260580, 685.78],
#  [58, 1751260700, 564.72],
#  [58, 1751260820, 513.13],
#  [58, 1751260940, 427.74],
#  [58, 1751261060, 608.88],
#  [58, 1751261180, 594.51],
#  [58, 1751261300, 562.95],
#  [59, 1751261420, 0.0],
#  [59, 1751261540, 0.0],
#  [59, 1751261660, 0.0],
#  [59, 1751261780, 1011.43],
#  [59, 1751261900, 623.79],
#  [59, 1751262020, 550.41],
#  [59, 1751262140, 510.94],
#  [59, 1751262260, 599.41],
#  [59, 1751262380, 566.16],
#  [59, 1751262500, 546.07],
#  [60, 1751262620, 0.0],
#  [60, 1751262740, 0.0],
#  [60, 1751262860, 0.0],
#  [60, 1751262980, 877.17],
#  [60, 1751263100, 631.86],
#  [60, 1751263220, 538.52],
#  [60, 1751263340, 495.55],
#  [60, 1751263460, 435.85],
#  [60, 1751263580, 412.48],
#  [60, 1751263700, 608.36],
#  [60, 1751263820, 588.76],
#  [61, 1751263940, 0.0],
#  [61, 1751264060, 0.0],
#  [61, 1751264180, 0.0],
#  [61, 1751264300, 0.0],
#  [61, 1751264420, 758.55],
#  [61, 1751264540, 596.54],
#  [61, 1751264660, 551.24],
#  [61, 1751264780, 423.92],
#  [61, 1751264900, 607.76],
#  [61, 1751265020, 574.74],
#  [61, 1751265140, 561.41],
#  [62, 1751265260, 0.0],
#  [62, 1751265380, 0.0],
#  [62, 1751265500, 0.0],
#  [62, 1751265620, 969.56],
#  [62, 1751265740, 599.44],
#  [62, 1751265860, 538.62],
#  [62, 1751265980, 517.7],
#  [62, 1751266100, 533.65],
#  [62, 1751266220, 578.71],
#  [62, 1751266340, 571.66],
#  [63, 1751266460, 0.0],
#  [63, 1751266580, 0.0],
#  [63, 1751266700, 0.0],
#  [63, 1751266820, 984.74],
#  [63, 1751266940, 697.94],
#  [63, 1751267060, 557.2],
#  [63, 1751267180, 519.7],
#  [63, 1751267300, 431.4],
#  [63, 1751267420, 612.0],
#  [63, 1751267540, 559.04],
#  [64, 1751267660, 0.0],
#  [64, 1751267780, 0.0],
#  [64, 1751267900, 0.0],
#  [64, 1751268020, 0.0],
#  [64, 1751268140, 696.53],
#  [64, 1751268260, 609.68],
#  [64, 1751268380, 538.19],
#  [64, 1751268500, 477.24],
#  [64, 1751268620, 394.76],
#  [64, 1751268740, 616.95],
#  [64, 1751268860, 573.15],
#  [64, 1751268980, 559.51],
#  [65, 1751269100, 0.0],
#  [65, 1751269220, 0.0],
#  [65, 1751269340, 0.0],
#  [65, 1751269460, 857.26],
#  [65, 1751269580, 573.4],
#  [65, 1751269700, 508.28],
#  [65, 1751269820, 503.87],
#  [65, 1751269940, 379.21],
#  [65, 1751270060, 624.25],
#  [65, 1751270180, 550.8],
#  [66, 1751270300, 0.0],
#  [66, 1751270420, 0.0],
#  [66, 1751270540, 0.0],
#  [66, 1751270660, 1007.85],
#  [66, 1751270780, 722.15],
#  [66, 1751270900, 541.49],
#  [66, 1751271020, 486.61],
#  [66, 1751271140, 408.25],
#  [66, 1751271260, 643.52],
#  [66, 1751271380, 599.68],
#  [75, 1751282420, 515.17],
#  [75, 1751282540, 474.84],
#  [75, 1751282660, 369.81],
#  [75, 1751282780, 624.74],
#  [75, 1751282900, 573.94],
#  [76, 1751283020, 0.0],
#  [76, 1751283140, 0.0],
#  [76, 1751283260, 0.0],
#  [76, 1751283380, 0.0],
#  [76, 1751283500, 1021.55],
#  [76, 1751283620, 641.86],
#  [76, 1751283740, 569.01],
#  [76, 1751283860, 483.03],
#  [76, 1751283980, 587.96],
#  [76, 1751284100, 576.74],
#  [76, 1751284220, 552.12],
#  [77, 1751284340, 0.0],
#  [77, 1751284460, 0.0],
#  [77, 1751284580, 0.0],
#  [77, 1751284700, 0.0],
#  [77, 1751284820, 661.7],
#  [77, 1751284940, 537.58],
#  [77, 1751285060, 498.84],
#  [77, 1751285180, 457.0],
#  [77, 1751285300, 357.17],
#  [77, 1751285420, 636.39],
#  [77, 1751285540, 601.19],
#  [78, 1751285660, 0.0],
#  [78, 1751285780, 0.0],
#  [78, 1751285900, 0.0],
#  [78, 1751286020, 0.0],
#  [78, 1751286140, 914.04],
#  [78, 1751286260, 588.87],
#  [78, 1751286380, 484.28],
#  [78, 1751286500, 332.99],
#  [78, 1751286620, 569.18],
#  [78, 1751286740, 567.59],
#  [79, 1751286860, 0.0],
#  [79, 1751286980, 0.0],
#  [79, 1751287100, 0.0],
#  [79, 1751287220, 0.0],
#  [79, 1751287340, 784.47],
#  [79, 1751287460, 560.29],
#  [79, 1751287580, 555.07],
#  [79, 1751287700, 482.36],
#  [79, 1751287820, 613.67],
#  [79, 1751287940, 574.91],
#  [79, 1751288060, 583.71],
#  [80, 1751288180, 0.0],
#  [80, 1751288300, 0.0],
#  [80, 1751288420, 0.0],
#  [80, 1751288540, 0.0],
#  [80, 1751288660, 671.39],
#  [80, 1751288780, 566.03],
#  [80, 1751288900, 513.73],
#  [80, 1751289020, 484.47],
#  [80, 1751289140, 367.34],
#  [80, 1751289260, 584.97],
#  [80, 1751289380, 570.66],
#  [81, 1751289500, 0.0],
#  [81, 1751289620, 0.0],
#  [81, 1751289740, 0.0],
#  [81, 1751289860, 840.86],
#  [81, 1751289980, 771.23],
#  [81, 1751290100, 566.86],
#  [81, 1751290220, 530.59],
#  [81, 1751290340, 349.03],
#  [81, 1751290460, 593.11],
#  [81, 1751290580, 590.22],
#  [82, 1751290700, 0.0],
#  [82, 1751290820, 0.0],
#  [82, 1751290940, 0.0],
#  [82, 1751291060, 0.0],
#  [82, 1751291180, 803.86],
#  [82, 1751291300, 567.86],
#  [82, 1751291420, 511.93],
#  [82, 1751291540, 431.22],
#  [82, 1751291660, 634.23],
#  [82, 1751291780, 565.44],
#  [82, 1751291900, 561.22],
#  [83, 1751292020, 0.0],
#  [83, 1751292140, 0.0],
#  [83, 1751292260, 0.0],
#  [83, 1751292380, 0.0],
#  [83, 1751292500, 667.55],
#  [83, 1751292620, 569.85],
#  [83, 1751292740, 530.03],
#  [83, 1751292860, 495.34],
#  [83, 1751292980, 593.62],
#  [83, 1751293100, 585.97],
#  [83, 1751293220, 563.43],
#  [84, 1751293340, 0.0],
#  [84, 1751293460, 0.0],
#  [84, 1751293580, 0.0],
#  [84, 1751293700, 998.64],
#  [84, 1751293820, 713.4],
#  [84, 1751293940, 548.56],
#  [84, 1751294060, 505.93],
#  [84, 1751294180, 443.12],
#  [84, 1751294300, 523.09],
#  [84, 1751294420, 611.19],
#  [85, 1751294660, 0.0],
#  [85, 1751294780, 0.0],
#  [85, 1751294900, 0.0],
#  [85, 1751295020, 0.0],
#  [85, 1751295140, 770.9],
#  [85, 1751295260, 562.48],
#  [85, 1751295380, 507.25],
#  [85, 1751295500, 411.89],
#  [85, 1751295620, 664.64],
#  [85, 1751295740, 623.12],
#  [85, 1751295860, 606.1],
#  [86, 1751295980, 0.0],
#  [86, 1751296100, 0.0],
#  [86, 1751296220, 0.0],
#  [86, 1751296340, 996.05],
#  [86, 1751296460, 594.6],
#  [86, 1751296580, 577.14],
#  [86, 1751296700, 529.27],
#  [86, 1751296820, 349.26],
#  [86, 1751296940, 571.22],
#  [86, 1751297060, 565.37],
#  [87, 1751297180, 0.0],
#  [87, 1751297300, 0.0],
#  [87, 1751297420, 0.0],
#  [87, 1751297540, 832.11],
#  [87, 1751297660, 734.84],
#  [87, 1751297780, 529.5],
#  [87, 1751297900, 490.88],
#  [87, 1751298020, 426.9],
#  [87, 1751298140, 345.68],
#  [87, 1751298260, 630.88],
#  [87, 1751298380, 614.3],
#  [88, 1751298500, 0.0],
#  [88, 1751298620, 0.0],
#  [88, 1751298740, 0.0],
#  [88, 1751298860, 0.0],
#  [88, 1751298980, 991.11],
#  [88, 1751299100, 649.18],
#  [88, 1751299220, 620.4],
#  [88, 1751299340, 512.11],
#  [88, 1751299460, 594.28],
#  [88, 1751299580, 585.19],
#  [88, 1751299700, 278.26],
#  [89, 1751299820, 0.0],
#  [89, 1751299940, 0.0],
#  [89, 1751300060, 0.0],
#  [89, 1751300180, 691.56],
#  [89, 1751300300, 558.82],
#  [89, 1751300420, 535.35],
#  [89, 1751300540, 495.95],
#  [89, 1751300660, 619.37],
#  [89, 1751300780, 580.55],
#  [89, 1751300900, 566.07],
#  [90, 1751301020, 0.0],
#  [90, 1751301140, 0.0],
#  [90, 1751301260, 0.0],
#  [90, 1751301380, 970.43],
#  [90, 1751301500, 704.91],
#  [90, 1751301620, 574.34],
#  [90, 1751301740, 525.57],
#  [90, 1751301860, 415.2],
#  [90, 1751301980, 579.09],
#  [90, 1751302100, 541.24],
#  [91, 1751302220, 0.0],
#  [91, 1751302340, 0.0],
#  [91, 1751302460, 0.0],
#  [91, 1751302580, 0.0],
#  [91, 1751302700, 959.29],
#  [91, 1751302820, 615.67],
#  [91, 1751302940, 561.27],
#  [91, 1751303060, 511.55],
#  [91, 1751303180, 440.77],
#  [91, 1751303300, 640.43],
#  [91, 1751303420, 600.43],
#  [91, 1751303540, 569.64],
#  [92, 1751303660, 0.0],
#  [92, 1751303780, 0.0],
#  [92, 1751303900, 0.0],
#  [92, 1751304020, 844.98],
#  [92, 1751304140, 585.34],
#  [92, 1751304260, 541.69],
#  [92, 1751304380, 514.56],
#  [92, 1751304500, 396.83],
#  [92, 1751304620, 582.64],
#  [92, 1751304740, 578.99],
#  ...]

# %%
import pandas as pd
df = pd.DataFrame(files['Sales Meter Flow Rate (MCF_Day).csv'], columns=['cycle_id', 'isotime', 'flow_rate'])
df
# Out:
#       cycle_id     isotime  flow_rate
# 0            0  1751184740       0.00
# 1            0  1751184860       0.00
# 2            0  1751184980       0.00
# 3            0  1751185100    1054.75
# 4            0  1751185220     650.64
# ...        ...         ...        ...
# 7193       680  1752048020     426.05
# 7194       680  1752048140     614.65
# 7195       680  1752048260     574.28
# 7196       680  1752048380     544.98
# 7197       681  1752048500       0.00
#
# [7198 rows x 3 columns]

# %%
def data_entries_manager():
    for file_name in files:
        if file_name == "Sales Meter Flow Rate (MCF_Day).csv":
            continue
        df[file_name] = None  # Create a new column for each file
        # Iterate through the DataFrame and for each isotime of flow rate (threshold_isotime)
        # find the corresponding isotime in the range of the thereshold_isotime_range
        # and assign the value from the corresponding file to the DataFrame      
        for i in range(0,7198):
            threshold_isotime = df.iloc[i]["isotime"]
            threshold_isotime_range = [threshold_isotime-60, threshold_isotime+61] # last is not included soo +61 to get +60
            for j in range(len(files[file_name])):
                if files[file_name][j][0] in range(threshold_isotime_range[0], threshold_isotime_range[1]):
                    # found the data entry
                    df.at[i,file_name] = files[file_name][j][1]
                    break
       
data_entries_manager()

# %%
df
# Out:
#       cycle_id     isotime  flow_rate Sales Meter Static Pressure (PSIA).csv  \
# 0            0  1751184740       0.00                                  97.06
# 1            0  1751184860       0.00                                  96.14
# 2            0  1751184980       0.00                                  95.36
# 3            0  1751185100    1054.75                                 113.09
# 4            0  1751185220     650.64                                 103.22
# ...        ...         ...        ...                                    ...
# 7193       680  1752048020     426.05                                  94.15
# 7194       680  1752048140     614.65                                  97.66
# 7195       680  1752048260     574.28                                   97.9
# 7196       680  1752048380     544.98                                   98.3
# 7197       681  1752048500       0.00                                   91.7
#
#      Line Pressure (PSIA).csv Casing Pressure (PSI).csv  \
# 0                       16.52                    204.41
# 1                       16.49                    207.57
# 2                       16.55                     211.6
# 3                       16.52                    215.27
# 4                       16.48                    215.22
# ...                       ...                       ...
# 7193                    16.52                    207.56
# 7194                    16.52                    205.56
# 7195                    16.49                    205.51
# 7196                    16.55                    204.19
# 7197                    16.52                    203.46
#
#      Tubing Pressure (PSI).csv Arrival Time Remaining.csv Arrival Speed.csv  \
# 0                       181.19                       30.0            979.15
# 1                       196.42                       30.0            979.15
# 2                       202.05                       30.0            979.15
# 3                       125.86                      29.64            979.15
# 4                       101.29                      26.63            979.15
# ...                        ...                        ...               ...
# 7193                     83.23                      22.34           1122.95
# 7194                      99.8                       30.0            1057.8
# 7195                     98.35                       30.0            1057.8
# 7196                      97.3                       30.0            1057.8
# 7197                    167.99                       30.0            1057.8
#
#      Current Non-Arrival Count.csv Down Hole Pressure (PSI).csv
# 0                              0.0                       291.14
# 1                              0.0                       299.94
# 2                              0.0                       306.28
# 3                              0.0                       305.62
# 4                              0.0                       289.12
# ...                            ...                          ...
# 7193                           0.0                       295.53
# 7194                           0.0                       291.17
# 7195                           0.0                       281.86
# 7196                           0.0                       268.87
# 7197                           0.0                       278.93
#
# [7198 rows x 11 columns]

# %% [markdown]
# Events

# %%
def generate_events_per_cycle(df, basic_event_funcs, complex_event_funcs):
    events = []
    for _, group in df.groupby('cycle_id'):
        basci_cycle_events = []
        for event_func in basic_event_funcs:
            if callable(event_func):
                basci_cycle_events.append(event_func(group))
        complex_cycle_events = []
        for event_func in complex_event_funcs:
            if callable(event_func):
                complex_cycle_events.append(event_func(group, basci_cycle_events))

        events.extend(basci_cycle_events)
        events.extend(complex_cycle_events)
    return events

# %% [markdown]
# basic:

# %%
def BasicPressureEvent(cycle_df, SG=0.6, hl=1000):
    cols = [
        "Tubing Pressure (PSI).csv",
        "Casing Pressure (PSI).csv",
        "Line Pressure (PSIA).csv"
    ]
    for col in cols:
        cycle_df[col] = cycle_df[col].astype(float)

    Pt_init = cycle_df.iloc[0]["Tubing Pressure (PSI).csv"]
    Pt_final = cycle_df.iloc[-1]["Tubing Pressure (PSI).csv"]
    Cp_init = cycle_df.iloc[0]["Casing Pressure (PSI).csv"]
    Cp_final = cycle_df.iloc[-1]["Casing Pressure (PSI).csv"]
    Pl_init = cycle_df.iloc[0]["Line Pressure (PSIA).csv"]
    Pl_final = cycle_df.iloc[-1]["Line Pressure (PSIA).csv"]

    delta_Pt = Pt_final - Pt_init
    delta_Cp = Cp_final - Cp_init
    delta_Pl = Pl_final - Pl_init
    ph = 0.433 * SG * hl

    return {"BasicPressureEvent": {
        "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
        "delta_Pt": round(float(delta_Pt), 3),
        "delta_Cp": round(float(delta_Cp), 3),
        "delta_Pl": round(float(delta_Pl), 3),
        "ph": round(float(ph), 3)
    }}

# %%
def CycleDurationEvent(cycle_df):
    # Start and end time of the cycle
    start_time = int(cycle_df.iloc[0]['isotime'])
    end_time = int(cycle_df.iloc[-1]['isotime'])
    total_duration = end_time - start_time

    # Flow duration: time when flow_rate was not zero
    non_zero = cycle_df[cycle_df['flow_rate'] > 0]
    if not non_zero.empty:
        flow_start = int(non_zero.iloc[0]['isotime'])
        flow_end = int(non_zero.iloc[-1]['isotime'])
        flow_duration = flow_end - flow_start
    else:
        flow_duration = 0

    # Shutin duration: time when flow_rate was zero
    zero = cycle_df[cycle_df['flow_rate'] == 0]
    if not zero.empty:
        shutin_start = int(zero.iloc[0]['isotime'])
        shutin_end = int(zero.iloc[-1]['isotime'])
        shutin_duration = shutin_end - shutin_start
    else:
        shutin_duration = 0

    return {"CycleDurationEvent": {
        "cycle_id": int(cycle_df.iloc[0]['cycle_id']),
        "start_time": start_time,
        "end_time": end_time,
        "total_duration": total_duration,
        "flow_duration": flow_duration,
        "shutin_duration": shutin_duration
    }}

# %%
def PlungerArrivalVelocityEvent(cycle_df):
    # Convert Arrival Speed.csv to float and get mean arrival speed for the cycle
    arrival_speed = cycle_df["Arrival Speed.csv"].astype(float).mean()
    return {
        "PlungerArrivalVelocityEvent": {
            "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
            "arrival_speed": round(float(arrival_speed), 3),  # m/s
        }
    }

# %% [markdown]
# complex:

# %%
def GasVolumeProducedEvent(cycle_df, events):
    # Find the CycleDurationEvent in the provided events
    cycle_duration_event = next((e["CycleDurationEvent"] for e in events if "CycleDurationEvent" in e), None)
    if cycle_duration_event is None:
        return {"GasVolumeProducedEvent": None}

    flow_duration = cycle_duration_event["flow_duration"]  # in seconds
    # Use mean flow_rate during the cycle (excluding zeros)
    non_zero_flow = cycle_df[cycle_df['flow_rate'] > 0]
    if not non_zero_flow.empty:
        avg_flow_rate = non_zero_flow['flow_rate'].mean()  # MCF/Day
        # Convert avg_flow_rate from MCF/Day to cubic meters/second
        # 1 MCF = 28.3168 m³, 1 day = 86400 seconds
        avg_flow_rate_m3s = avg_flow_rate * 28.3168 / 86400
        gas_volume = avg_flow_rate_m3s * flow_duration  # in cubic meters
    else:
        gas_volume = 0.0

    return {
        "GasVolumeProducedEvent": {
            "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
            "gas_volume": round(float(gas_volume), 3),  # cubic meters
            "CycleDurationEvent": cycle_duration_event  # in seconds
        }
    }

# %%
def CycleDataEvent(cycle_df, events):
    event_log = {
        "cycle_id": int(cycle_df.iloc[0]["cycle_id"])
    }
    # Map event names to their data
    for event in events:
        if "BasicPressureEvent" in event:
            event_log["basicPressureEvent"] = event["BasicPressureEvent"]
        elif "CycleDurationEvent" in event:
            event_log["cycleDurationEvent"] = event["CycleDurationEvent"]
        elif "GasVolumeProducedEvent" in event:
            event_log["gasVolumeProduced"] = event["GasVolumeProducedEvent"]
        elif "PlungerArrivalVelocityEvent" in event:
            event_log["velocityEvent"] = event["PlungerArrivalVelocityEvent"]
    return {"CycleDataEvent": event_log}

# %%
def UnexpectedLowCasingPressure(cycle_df, events, threshold=-5.0):
    basic_pressure_event = next((e["BasicPressureEvent"] for e in events if "BasicPressureEvent" in e))

    delta_cp = basic_pressure_event['delta_Cp']
    if delta_cp < threshold:
        return {
            "UnexpectedLowCasingPressure": {
                "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
                "BasicPressureEvent": basic_pressure_event,
                "description": "Abnormally low casing pressure change detected."
            }
        }
    return None

# %%
def PlungerArrivalStatusEvent(cycle_df, events):
    # non_arrival: True if all Current Non-Arrival Count.csv > 0, else False
    non_arrival = cycle_df["Current Non-Arrival Count.csv"].astype(float).max() > 0

    unexpected_casing_pressure = next((e["UnexpectedLowCasingPressure"] for e in events if "UnexpectedLowCasingPressure" in e), None)

    return {
        "PlungerArrivalStatusEvent": {
            "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
            "non_arrival": bool(non_arrival),
            "unexpected_casing_pressure": bool(unexpected_casing_pressure),
            "UnexpectedLowCasingPressure": unexpected_casing_pressure,
            "description": (
                "Plunger did not arrive; " if non_arrival else "Plunger arrived; "
            ) + (
                "Unexpected low casing pressure detected."
                if unexpected_casing_pressure
                else "Casing pressure normal."
            ),
        }
    }

# %%
def PlungerUnsafeVelocityEvent(cycle_df, events, safety_threshold=2.5):
    # Find the PlungerArrivalVelocityEvent in the provided events
    velocity_event = next((e["PlungerArrivalVelocityEvent"] for e in events if "PlungerArrivalVelocityEvent" in e), None)
    if velocity_event is None:
        return None

    arrival_speed = velocity_event["arrival_speed"]
    unsafe = arrival_speed > safety_threshold

    if unsafe:
        return {
            "PlungerUnsafeVelocity": {
                "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
                "arrival_speed": arrival_speed,
                "velocityEvent": velocity_event,
                "description": (
                    "The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival "
                    "at the surface exceeds a predefined safety threshold. This indicates potentially dangerous "
                    "impact forces that could damage equipment or signal aggressive flow conditions. "
                    "Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear."
                ),
                "safety_threshold": safety_threshold
            }
        }
    return None

# %%
def UnexpectedLowFlow(cycle_df, events, volume_threshold=10.0):
    gas_volume_event = next((e["GasVolumeProducedEvent"] for e in events if "GasVolumeProducedEvent" in e), None)
    if gas_volume_event is None:
        return None

    gas_volume = gas_volume_event["gas_volume"]
    if gas_volume < volume_threshold:
        return {
            "UnexpectedLowFlow": {
                "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
                "gas_volume": gas_volume,
                "volume_threshold": volume_threshold,
                "description": (
                    "The UnexpectedLowFlow event is raised when the gas volume produced during a cycle is significantly lower than expected. "
                    "This may indicate underperformance, early plunger fallback, or poor liquid unloading."
                ),
            }
        }
    return None

# %%
def UnexpectedLowCycleDuration(cycle_df, events, total_duration_threshold=600, flow_duration_threshold=300, shutin_duration_threshold=300):
    # Find the CycleDurationEvent in the provided events
    cycle_duration_event = next((e["CycleDurationEvent"] for e in events if "CycleDurationEvent" in e), None)
    if cycle_duration_event is None:
        return None

    total_duration = cycle_duration_event["total_duration"]
    flow_duration = cycle_duration_event["flow_duration"]
    shutin_duration = cycle_duration_event["shutin_duration"]

    is_short = (
        total_duration < total_duration_threshold or
        flow_duration < flow_duration_threshold or
        shutin_duration < shutin_duration_threshold
    )

    if is_short:
        return {
            "UnexpectedLowCycleDuration": {
                "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
                "total_duration": total_duration,
                "flow_duration": flow_duration,
                "shutin_duration": shutin_duration,
                "thresholds": {
                    "total_duration": total_duration_threshold,
                    "flow_duration": flow_duration_threshold,
                    "shutin_duration": shutin_duration_threshold
                },
                "CycleDurationEvent": cycle_duration_event,
                "description": (
                    "The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. "
                    "Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. "
                    "Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes."
                )
            }
        }
    return None

# %%
def UnexpectedHighCycleDuration(cycle_df, events, total_duration_threshold=7200, flow_duration_threshold=3600, shutin_duration_threshold=3600):
    cycle_duration_event = next((e["CycleDurationEvent"] for e in events if "CycleDurationEvent" in e), None)
    if cycle_duration_event is None:
        return None

    total_duration = cycle_duration_event["total_duration"]
    flow_duration = cycle_duration_event["flow_duration"]
    shutin_duration = cycle_duration_event["shutin_duration"]

    is_long = (
        total_duration > total_duration_threshold or
        flow_duration > flow_duration_threshold or
        shutin_duration > shutin_duration_threshold
    )

    if is_long:
        return {
            "UnexpectedHighCycleDuration": {
                "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
                "total_duration": total_duration,
                "flow_duration": flow_duration,
                "shutin_duration": shutin_duration,
                "thresholds": {
                    "total_duration": total_duration_threshold,
                    "flow_duration": flow_duration_threshold,
                    "shutin_duration": shutin_duration_threshold
                },
                "CycleDurationEvent": cycle_duration_event,
                "description": (
                    "The UnexpectedHighCycleDuration event highlights cycles that exceed acceptable time limits, "
                    "particularly during flow or shut-in phases. This can indicate poor liquid unloading, sluggish arrival, "
                    "excessive shut-in, or gas buildup delays. By identifying these long cycles, operators can rebalance lift "
                    "frequency, flow durations, and shut-in strategies to restore cycle efficiency."
                )
            }
        }
    return None

# %%
def CycleAnomalyEvent(cycle_df, events):
    # Map anomaly event keys to their output names and descriptions
    anomaly_map = {
        "PlungerUnsafeVelocity": "plungerUnsafeVelocity",
        "PlungerNonArrival": "plungerNonArrival",
        "UnexpectedLowCasingPressure": "UnexpectedCasingPressure",
        "UnexpectedLowFlow": "UnexpectedLowFlow",
        "UnexpectedLowCycleDuration": "UnexpectedLowCycleDuration",
        "UnexpectedHighCycleDuration": "UnexpectedHighCycleDuration"
    }

    # Find which anomaly events are present in the events list
    triggered = {}
    for event in events:
        for key, output_name in anomaly_map.items():
            if key in event:
                triggered[output_name] = event[key]

    if triggered:
        return {
            "CycleAnomalyEvent": {
                "cycle_id": int(cycle_df.iloc[0]["cycle_id"]),
                "anomalies": list(triggered.keys()),
                "details": triggered,
                "description": (
                    "The CycleAnomalyEvent is a composite event designed to encapsulate critical failures, "
                    "inefficiencies, or safety violations occurring during a plunger lift cycle. It is triggered "
                    "whenever one or more constituent anomaly events occur, including PlungerNonArrival, "
                    "PlungerUnsafeVelocity, UnexpectedLowCasingPressure, UnexpectedLowFlow, "
                    "UnexpectedLowCycleDuration, and UnexpectedHighCycleDuration. This wrapper event provides "
                    "a high-level signal indicating that a cycle has deviated from expected operational behavior. "
                    "It supports automated monitoring and root-cause analysis by summarizing which specific "
                    "anomalies occurred, helping identify equipment issues, cycle misconfigurations, or poor lift "
                    "conditions that warrant intervention."
                )
            }
        }
    return None

# %%
generate_events_per_cycle(
    df, 
    [BasicPressureEvent, CycleDurationEvent, PlungerArrivalVelocityEvent],
    [GasVolumeProducedEvent, CycleDataEvent, UnexpectedLowCasingPressure, PlungerArrivalStatusEvent, PlungerUnsafeVelocityEvent, UnexpectedLowCycleDuration, UnexpectedLowFlow, CycleAnomalyEvent]
)
# Out:
# [{'BasicPressureEvent': {'cycle_id': 0,
#    'delta_Pt': -83.08,
#    'delta_Cp': -0.3,
#    'delta_Pl': 0.0,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 0,
#    'start_time': 1751184740,
#    'end_time': 1751185820,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 0, 'arrival_speed': 1021.666}},
#  {'GasVolumeProducedEvent': {'cycle_id': 0,
#    'gas_volume': 153.868,
#    'CycleDurationEvent': {'cycle_id': 0,
#     'start_time': 1751184740,
#     'end_time': 1751185820,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 0,
#    'basicPressureEvent': {'cycle_id': 0,
#     'delta_Pt': -83.08,
#     'delta_Cp': -0.3,
#     'delta_Pl': 0.0,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 0,
#     'start_time': 1751184740,
#     'end_time': 1751185820,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 0, 'arrival_speed': 1021.666}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 0,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 0,
#    'arrival_speed': 1021.666,
#    'velocityEvent': {'cycle_id': 0, 'arrival_speed': 1021.666},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 0,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 0,
#     'start_time': 1751184740,
#     'end_time': 1751185820,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 1,
#    'delta_Pt': -76.33,
#    'delta_Cp': -0.19,
#    'delta_Pl': 0.03,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 1,
#    'start_time': 1751185940,
#    'end_time': 1751187140,
#    'total_duration': 1200,
#    'flow_duration': 720,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 1, 'arrival_speed': 1062.681}},
#  {'GasVolumeProducedEvent': {'cycle_id': 1,
#    'gas_volume': 130.967,
#    'CycleDurationEvent': {'cycle_id': 1,
#     'start_time': 1751185940,
#     'end_time': 1751187140,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 1,
#    'basicPressureEvent': {'cycle_id': 1,
#     'delta_Pt': -76.33,
#     'delta_Cp': -0.19,
#     'delta_Pl': 0.03,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 1,
#     'start_time': 1751185940,
#     'end_time': 1751187140,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 1, 'arrival_speed': 1062.681}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 1,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 1,
#    'arrival_speed': 1062.681,
#    'velocityEvent': {'cycle_id': 1, 'arrival_speed': 1062.681},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 2,
#    'delta_Pt': -27.09,
#    'delta_Cp': 0.52,
#    'delta_Pl': -0.01,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 2,
#    'start_time': 1751187260,
#    'end_time': 1751188460,
#    'total_duration': 1200,
#    'flow_duration': 720,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 2, 'arrival_speed': 965.685}},
#  {'GasVolumeProducedEvent': {'cycle_id': 2,
#    'gas_volume': 118.031,
#    'CycleDurationEvent': {'cycle_id': 2,
#     'start_time': 1751187260,
#     'end_time': 1751188460,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 2,
#    'basicPressureEvent': {'cycle_id': 2,
#     'delta_Pt': -27.09,
#     'delta_Cp': 0.52,
#     'delta_Pl': -0.01,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 2,
#     'start_time': 1751187260,
#     'end_time': 1751188460,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 2, 'arrival_speed': 965.685}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 2,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 2,
#    'arrival_speed': 965.685,
#    'velocityEvent': {'cycle_id': 2, 'arrival_speed': 965.685},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 3,
#    'delta_Pt': -55.15,
#    'delta_Cp': -2.45,
#    'delta_Pl': 0.06,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 3,
#    'start_time': 1751188580,
#    'end_time': 1751189780,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 3, 'arrival_speed': 1041.688}},
#  {'GasVolumeProducedEvent': {'cycle_id': 3,
#    'gas_volume': 136.451,
#    'CycleDurationEvent': {'cycle_id': 3,
#     'start_time': 1751188580,
#     'end_time': 1751189780,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 3,
#    'basicPressureEvent': {'cycle_id': 3,
#     'delta_Pt': -55.15,
#     'delta_Cp': -2.45,
#     'delta_Pl': 0.06,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 3,
#     'start_time': 1751188580,
#     'end_time': 1751189780,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 3, 'arrival_speed': 1041.688}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 3,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 3,
#    'arrival_speed': 1041.688,
#    'velocityEvent': {'cycle_id': 3, 'arrival_speed': 1041.688},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 3,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 3,
#     'start_time': 1751188580,
#     'end_time': 1751189780,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 4,
#    'delta_Pt': -75.2,
#    'delta_Cp': -2.59,
#    'delta_Pl': 0.0,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 4,
#    'start_time': 1751189900,
#    'end_time': 1751191340,
#    'total_duration': 1440,
#    'flow_duration': 1080,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 4, 'arrival_speed': 803.67}},
#  {'GasVolumeProducedEvent': {'cycle_id': 4,
#    'gas_volume': 191.53,
#    'CycleDurationEvent': {'cycle_id': 4,
#     'start_time': 1751189900,
#     'end_time': 1751191340,
#     'total_duration': 1440,
#     'flow_duration': 1080,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 4,
#    'basicPressureEvent': {'cycle_id': 4,
#     'delta_Pt': -75.2,
#     'delta_Cp': -2.59,
#     'delta_Pl': 0.0,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 4,
#     'start_time': 1751189900,
#     'end_time': 1751191340,
#     'total_duration': 1440,
#     'flow_duration': 1080,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 4, 'arrival_speed': 803.67}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 4,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 4,
#    'arrival_speed': 803.67,
#    'velocityEvent': {'cycle_id': 4, 'arrival_speed': 803.67},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 4,
#    'total_duration': 1440,
#    'flow_duration': 1080,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 4,
#     'start_time': 1751189900,
#     'end_time': 1751191340,
#     'total_duration': 1440,
#     'flow_duration': 1080,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 5,
#    'delta_Pt': -70.53,
#    'delta_Cp': 1.59,
#    'delta_Pl': -0.04,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 5,
#    'start_time': 1751191460,
#    'end_time': 1751192660,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 5, 'arrival_speed': 746.956}},
#  {'GasVolumeProducedEvent': {'cycle_id': 5,
#    'gas_volume': 168.102,
#    'CycleDurationEvent': {'cycle_id': 5,
#     'start_time': 1751191460,
#     'end_time': 1751192660,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 5,
#    'basicPressureEvent': {'cycle_id': 5,
#     'delta_Pt': -70.53,
#     'delta_Cp': 1.59,
#     'delta_Pl': -0.04,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 5,
#     'start_time': 1751191460,
#     'end_time': 1751192660,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 5, 'arrival_speed': 746.956}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 5,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 5,
#    'arrival_speed': 746.956,
#    'velocityEvent': {'cycle_id': 5, 'arrival_speed': 746.956},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 5,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 5,
#     'start_time': 1751191460,
#     'end_time': 1751192660,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 6,
#    'delta_Pt': -78.52,
#    'delta_Cp': -0.88,
#    'delta_Pl': -0.03,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 6,
#    'start_time': 1751192780,
#    'end_time': 1751193860,
#    'total_duration': 1080,
#    'flow_duration': 600,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 6, 'arrival_speed': 1002.577}},
#  {'GasVolumeProducedEvent': {'cycle_id': 6,
#    'gas_volume': 115.41,
#    'CycleDurationEvent': {'cycle_id': 6,
#     'start_time': 1751192780,
#     'end_time': 1751193860,
#     'total_duration': 1080,
#     'flow_duration': 600,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 6,
#    'basicPressureEvent': {'cycle_id': 6,
#     'delta_Pt': -78.52,
#     'delta_Cp': -0.88,
#     'delta_Pl': -0.03,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 6,
#     'start_time': 1751192780,
#     'end_time': 1751193860,
#     'total_duration': 1080,
#     'flow_duration': 600,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 6, 'arrival_speed': 1002.577}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 6,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 6,
#    'arrival_speed': 1002.577,
#    'velocityEvent': {'cycle_id': 6, 'arrival_speed': 1002.577},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 7,
#    'delta_Pt': -68.06,
#    'delta_Cp': 0.85,
#    'delta_Pl': 0.01,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 7,
#    'start_time': 1751193980,
#    'end_time': 1751195060,
#    'total_duration': 1080,
#    'flow_duration': 600,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 7, 'arrival_speed': 1073.507}},
#  {'GasVolumeProducedEvent': {'cycle_id': 7,
#    'gas_volume': 120.892,
#    'CycleDurationEvent': {'cycle_id': 7,
#     'start_time': 1751193980,
#     'end_time': 1751195060,
#     'total_duration': 1080,
#     'flow_duration': 600,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 7,
#    'basicPressureEvent': {'cycle_id': 7,
#     'delta_Pt': -68.06,
#     'delta_Cp': 0.85,
#     'delta_Pl': 0.01,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 7,
#     'start_time': 1751193980,
#     'end_time': 1751195060,
#     'total_duration': 1080,
#     'flow_duration': 600,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 7, 'arrival_speed': 1073.507}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 7,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 7,
#    'arrival_speed': 1073.507,
#    'velocityEvent': {'cycle_id': 7, 'arrival_speed': 1073.507},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 8,
#    'delta_Pt': -47.78,
#    'delta_Cp': 0.52,
#    'delta_Pl': -0.05,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 8,
#    'start_time': 1751195180,
#    'end_time': 1751196500,
#    'total_duration': 1320,
#    'flow_duration': 840,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 8, 'arrival_speed': 1089.135}},
#  {'GasVolumeProducedEvent': {'cycle_id': 8,
#    'gas_volume': 149.964,
#    'CycleDurationEvent': {'cycle_id': 8,
#     'start_time': 1751195180,
#     'end_time': 1751196500,
#     'total_duration': 1320,
#     'flow_duration': 840,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 8,
#    'basicPressureEvent': {'cycle_id': 8,
#     'delta_Pt': -47.78,
#     'delta_Cp': 0.52,
#     'delta_Pl': -0.05,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 8,
#     'start_time': 1751195180,
#     'end_time': 1751196500,
#     'total_duration': 1320,
#     'flow_duration': 840,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 8, 'arrival_speed': 1089.135}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 8,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 8,
#    'arrival_speed': 1089.135,
#    'velocityEvent': {'cycle_id': 8, 'arrival_speed': 1089.135},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 9,
#    'delta_Pt': -84.81,
#    'delta_Cp': 0.19,
#    'delta_Pl': 0.03,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 9,
#    'start_time': 1751196620,
#    'end_time': 1751197700,
#    'total_duration': 1080,
#    'flow_duration': 600,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 9, 'arrival_speed': 895.878}},
#  {'GasVolumeProducedEvent': {'cycle_id': 9,
#    'gas_volume': 102.457,
#    'CycleDurationEvent': {'cycle_id': 9,
#     'start_time': 1751196620,
#     'end_time': 1751197700,
#     'total_duration': 1080,
#     'flow_duration': 600,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 9,
#    'basicPressureEvent': {'cycle_id': 9,
#     'delta_Pt': -84.81,
#     'delta_Cp': 0.19,
#     'delta_Pl': 0.03,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 9,
#     'start_time': 1751196620,
#     'end_time': 1751197700,
#     'total_duration': 1080,
#     'flow_duration': 600,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 9, 'arrival_speed': 895.878}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 9,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 9,
#    'arrival_speed': 895.878,
#    'velocityEvent': {'cycle_id': 9, 'arrival_speed': 895.878},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 10,
#    'delta_Pt': -73.79,
#    'delta_Cp': 1.14,
#    'delta_Pl': 0.07,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 10,
#    'start_time': 1751197820,
#    'end_time': 1751198900,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 10, 'arrival_speed': 1113.487}},
#  {'GasVolumeProducedEvent': {'cycle_id': 10,
#    'gas_volume': 127.704,
#    'CycleDurationEvent': {'cycle_id': 10,
#     'start_time': 1751197820,
#     'end_time': 1751198900,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 10,
#    'basicPressureEvent': {'cycle_id': 10,
#     'delta_Pt': -73.79,
#     'delta_Cp': 1.14,
#     'delta_Pl': 0.07,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 10,
#     'start_time': 1751197820,
#     'end_time': 1751198900,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 10, 'arrival_speed': 1113.487}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 10,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 10,
#    'arrival_speed': 1113.487,
#    'velocityEvent': {'cycle_id': 10, 'arrival_speed': 1113.487},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 10,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 10,
#     'start_time': 1751197820,
#     'end_time': 1751198900,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 11,
#    'delta_Pt': -26.89,
#    'delta_Cp': 1.02,
#    'delta_Pl': 0.02,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 11,
#    'start_time': 1751199020,
#    'end_time': 1751200220,
#    'total_duration': 1200,
#    'flow_duration': 720,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 11, 'arrival_speed': 1047.104}},
#  {'GasVolumeProducedEvent': {'cycle_id': 11,
#    'gas_volume': 130.811,
#    'CycleDurationEvent': {'cycle_id': 11,
#     'start_time': 1751199020,
#     'end_time': 1751200220,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 11,
#    'basicPressureEvent': {'cycle_id': 11,
#     'delta_Pt': -26.89,
#     'delta_Cp': 1.02,
#     'delta_Pl': 0.02,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 11,
#     'start_time': 1751199020,
#     'end_time': 1751200220,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 11, 'arrival_speed': 1047.104}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 11,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 11,
#    'arrival_speed': 1047.104,
#    'velocityEvent': {'cycle_id': 11, 'arrival_speed': 1047.104},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 12,
#    'delta_Pt': -56.8,
#    'delta_Cp': 1.51,
#    'delta_Pl': 0.04,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 12,
#    'start_time': 1751200340,
#    'end_time': 1751201540,
#    'total_duration': 1200,
#    'flow_duration': 720,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 12, 'arrival_speed': 971.365}},
#  {'GasVolumeProducedEvent': {'cycle_id': 12,
#    'gas_volume': 138.274,
#    'CycleDurationEvent': {'cycle_id': 12,
#     'start_time': 1751200340,
#     'end_time': 1751201540,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 12,
#    'basicPressureEvent': {'cycle_id': 12,
#     'delta_Pt': -56.8,
#     'delta_Cp': 1.51,
#     'delta_Pl': 0.04,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 12,
#     'start_time': 1751200340,
#     'end_time': 1751201540,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 12, 'arrival_speed': 971.365}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 12,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 12,
#    'arrival_speed': 971.365,
#    'velocityEvent': {'cycle_id': 12, 'arrival_speed': 971.365},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 13,
#    'delta_Pt': -76.56,
#    'delta_Cp': -0.16,
#    'delta_Pl': -0.05,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 13,
#    'start_time': 1751201660,
#    'end_time': 1751202860,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 13, 'arrival_speed': 1008.041}},
#  {'GasVolumeProducedEvent': {'cycle_id': 13,
#    'gas_volume': 169.529,
#    'CycleDurationEvent': {'cycle_id': 13,
#     'start_time': 1751201660,
#     'end_time': 1751202860,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 13,
#    'basicPressureEvent': {'cycle_id': 13,
#     'delta_Pt': -76.56,
#     'delta_Cp': -0.16,
#     'delta_Pl': -0.05,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 13,
#     'start_time': 1751201660,
#     'end_time': 1751202860,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 13, 'arrival_speed': 1008.041}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 13,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 13,
#    'arrival_speed': 1008.041,
#    'velocityEvent': {'cycle_id': 13, 'arrival_speed': 1008.041},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 13,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 13,
#     'start_time': 1751201660,
#     'end_time': 1751202860,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 14,
#    'delta_Pt': -82.46,
#    'delta_Cp': 0.51,
#    'delta_Pl': 0.03,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 14,
#    'start_time': 1751202980,
#    'end_time': 1751204060,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 14, 'arrival_speed': 1006.21}},
#  {'GasVolumeProducedEvent': {'cycle_id': 14,
#    'gas_volume': 139.041,
#    'CycleDurationEvent': {'cycle_id': 14,
#     'start_time': 1751202980,
#     'end_time': 1751204060,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 14,
#    'basicPressureEvent': {'cycle_id': 14,
#     'delta_Pt': -82.46,
#     'delta_Cp': 0.51,
#     'delta_Pl': 0.03,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 14,
#     'start_time': 1751202980,
#     'end_time': 1751204060,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 14, 'arrival_speed': 1006.21}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 14,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 14,
#    'arrival_speed': 1006.21,
#    'velocityEvent': {'cycle_id': 14, 'arrival_speed': 1006.21},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 14,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 14,
#     'start_time': 1751202980,
#     'end_time': 1751204060,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 15,
#    'delta_Pt': -59.48,
#    'delta_Cp': -0.38,
#    'delta_Pl': 0.02,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 15,
#    'start_time': 1751204180,
#    'end_time': 1751205500,
#    'total_duration': 1320,
#    'flow_duration': 840,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 15, 'arrival_speed': 1029.283}},
#  {'GasVolumeProducedEvent': {'cycle_id': 15,
#    'gas_volume': 152.122,
#    'CycleDurationEvent': {'cycle_id': 15,
#     'start_time': 1751204180,
#     'end_time': 1751205500,
#     'total_duration': 1320,
#     'flow_duration': 840,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 15,
#    'basicPressureEvent': {'cycle_id': 15,
#     'delta_Pt': -59.48,
#     'delta_Cp': -0.38,
#     'delta_Pl': 0.02,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 15,
#     'start_time': 1751204180,
#     'end_time': 1751205500,
#     'total_duration': 1320,
#     'flow_duration': 840,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 15, 'arrival_speed': 1029.283}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 15,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 15,
#    'arrival_speed': 1029.283,
#    'velocityEvent': {'cycle_id': 15, 'arrival_speed': 1029.283},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 16,
#    'delta_Pt': -90.16,
#    'delta_Cp': 0.17,
#    'delta_Pl': 0.03,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 16,
#    'start_time': 1751205620,
#    'end_time': 1751206580,
#    'total_duration': 960,
#    'flow_duration': 600,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 16, 'arrival_speed': 954.982}},
#  {'GasVolumeProducedEvent': {'cycle_id': 16,
#    'gas_volume': 118.641,
#    'CycleDurationEvent': {'cycle_id': 16,
#     'start_time': 1751205620,
#     'end_time': 1751206580,
#     'total_duration': 960,
#     'flow_duration': 600,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 16,
#    'basicPressureEvent': {'cycle_id': 16,
#     'delta_Pt': -90.16,
#     'delta_Cp': 0.17,
#     'delta_Pl': 0.03,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 16,
#     'start_time': 1751205620,
#     'end_time': 1751206580,
#     'total_duration': 960,
#     'flow_duration': 600,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 16, 'arrival_speed': 954.982}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 16,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 16,
#    'arrival_speed': 954.982,
#    'velocityEvent': {'cycle_id': 16, 'arrival_speed': 954.982},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 16,
#    'total_duration': 960,
#    'flow_duration': 600,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 16,
#     'start_time': 1751205620,
#     'end_time': 1751206580,
#     'total_duration': 960,
#     'flow_duration': 600,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 17,
#    'delta_Pt': -39.16,
#    'delta_Cp': 0.1,
#    'delta_Pl': -0.02,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 17,
#    'start_time': 1751206700,
#    'end_time': 1751208020,
#    'total_duration': 1320,
#    'flow_duration': 840,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 17, 'arrival_speed': 1091.917}},
#  {'GasVolumeProducedEvent': {'cycle_id': 17,
#    'gas_volume': 145.315,
#    'CycleDurationEvent': {'cycle_id': 17,
#     'start_time': 1751206700,
#     'end_time': 1751208020,
#     'total_duration': 1320,
#     'flow_duration': 840,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 17,
#    'basicPressureEvent': {'cycle_id': 17,
#     'delta_Pt': -39.16,
#     'delta_Cp': 0.1,
#     'delta_Pl': -0.02,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 17,
#     'start_time': 1751206700,
#     'end_time': 1751208020,
#     'total_duration': 1320,
#     'flow_duration': 840,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 17, 'arrival_speed': 1091.917}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 17,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 17,
#    'arrival_speed': 1091.917,
#    'velocityEvent': {'cycle_id': 17, 'arrival_speed': 1091.917},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 18,
#    'delta_Pt': -74.01,
#    'delta_Cp': 1.07,
#    'delta_Pl': 0.01,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 18,
#    'start_time': 1751208140,
#    'end_time': 1751209340,
#    'total_duration': 1200,
#    'flow_duration': 720,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 18, 'arrival_speed': 882.627}},
#  {'GasVolumeProducedEvent': {'cycle_id': 18,
#    'gas_volume': 135.903,
#    'CycleDurationEvent': {'cycle_id': 18,
#     'start_time': 1751208140,
#     'end_time': 1751209340,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 18,
#    'basicPressureEvent': {'cycle_id': 18,
#     'delta_Pt': -74.01,
#     'delta_Cp': 1.07,
#     'delta_Pl': 0.01,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 18,
#     'start_time': 1751208140,
#     'end_time': 1751209340,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 18, 'arrival_speed': 882.627}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 18,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 18,
#    'arrival_speed': 882.627,
#    'velocityEvent': {'cycle_id': 18, 'arrival_speed': 882.627},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 19,
#    'delta_Pt': -76.48,
#    'delta_Cp': -1.38,
#    'delta_Pl': 0.0,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 19,
#    'start_time': 1751209460,
#    'end_time': 1751210660,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 19, 'arrival_speed': 1018.971}},
#  {'GasVolumeProducedEvent': {'cycle_id': 19,
#    'gas_volume': 158.683,
#    'CycleDurationEvent': {'cycle_id': 19,
#     'start_time': 1751209460,
#     'end_time': 1751210660,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 19,
#    'basicPressureEvent': {'cycle_id': 19,
#     'delta_Pt': -76.48,
#     'delta_Cp': -1.38,
#     'delta_Pl': 0.0,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 19,
#     'start_time': 1751209460,
#     'end_time': 1751210660,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 19, 'arrival_speed': 1018.971}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 19,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 19,
#    'arrival_speed': 1018.971,
#    'velocityEvent': {'cycle_id': 19, 'arrival_speed': 1018.971},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 19,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 19,
#     'start_time': 1751209460,
#     'end_time': 1751210660,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 20,
#    'delta_Pt': -80.41,
#    'delta_Cp': 0.13,
#    'delta_Pl': 0.02,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 20,
#    'start_time': 1751210780,
#    'end_time': 1751211860,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 20, 'arrival_speed': 897.996}},
#  {'GasVolumeProducedEvent': {'cycle_id': 20,
#    'gas_volume': 149.741,
#    'CycleDurationEvent': {'cycle_id': 20,
#     'start_time': 1751210780,
#     'end_time': 1751211860,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 20,
#    'basicPressureEvent': {'cycle_id': 20,
#     'delta_Pt': -80.41,
#     'delta_Cp': 0.13,
#     'delta_Pl': 0.02,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 20,
#     'start_time': 1751210780,
#     'end_time': 1751211860,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 20, 'arrival_speed': 897.996}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 20,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 20,
#    'arrival_speed': 897.996,
#    'velocityEvent': {'cycle_id': 20, 'arrival_speed': 897.996},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 20,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 20,
#     'start_time': 1751210780,
#     'end_time': 1751211860,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 21,
#    'delta_Pt': -56.71,
#    'delta_Cp': 0.74,
#    'delta_Pl': -0.05,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 21,
#    'start_time': 1751211980,
#    'end_time': 1751213180,
#    'total_duration': 1200,
#    'flow_duration': 720,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 21, 'arrival_speed': 1063.045}},
#  {'GasVolumeProducedEvent': {'cycle_id': 21,
#    'gas_volume': 141.534,
#    'CycleDurationEvent': {'cycle_id': 21,
#     'start_time': 1751211980,
#     'end_time': 1751213180,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 21,
#    'basicPressureEvent': {'cycle_id': 21,
#     'delta_Pt': -56.71,
#     'delta_Cp': 0.74,
#     'delta_Pl': -0.05,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 21,
#     'start_time': 1751211980,
#     'end_time': 1751213180,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 21, 'arrival_speed': 1063.045}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 21,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 21,
#    'arrival_speed': 1063.045,
#    'velocityEvent': {'cycle_id': 21, 'arrival_speed': 1063.045},
# ...
#    'cycleDurationEvent': {'cycle_id': 84,
#     'start_time': 1751293340,
#     'end_time': 1751294420,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 84, 'arrival_speed': 966.95}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 84,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 84,
#    'arrival_speed': 966.95,
#    'velocityEvent': {'cycle_id': 84, 'arrival_speed': 966.95},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 84,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 84,
#     'start_time': 1751293340,
#     'end_time': 1751294420,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 85,
#    'delta_Pt': 3.48,
#    'delta_Cp': -0.79,
#    'delta_Pl': 0.0,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 85,
#    'start_time': 1751294660,
#    'end_time': 1751295860,
#    'total_duration': 1200,
#    'flow_duration': 720,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 85, 'arrival_speed': 904.365}},
#  {'GasVolumeProducedEvent': {'cycle_id': 85,
#    'gas_volume': 139.776,
#    'CycleDurationEvent': {'cycle_id': 85,
#     'start_time': 1751294660,
#     'end_time': 1751295860,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 85,
#    'basicPressureEvent': {'cycle_id': 85,
#     'delta_Pt': 3.48,
#     'delta_Cp': -0.79,
#     'delta_Pl': 0.0,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 85,
#     'start_time': 1751294660,
#     'end_time': 1751295860,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 85, 'arrival_speed': 904.365}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 85,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 85,
#    'arrival_speed': 904.365,
#    'velocityEvent': {'cycle_id': 85, 'arrival_speed': 904.365},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 86,
#    'delta_Pt': -80.26,
#    'delta_Cp': 0.04,
#    'delta_Pl': -0.01,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 86,
#    'start_time': 1751295980,
#    'end_time': 1751297060,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 86, 'arrival_speed': 1024.963}},
#  {'GasVolumeProducedEvent': {'cycle_id': 86,
#    'gas_volume': 141.008,
#    'CycleDurationEvent': {'cycle_id': 86,
#     'start_time': 1751295980,
#     'end_time': 1751297060,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 86,
#    'basicPressureEvent': {'cycle_id': 86,
#     'delta_Pt': -80.26,
#     'delta_Cp': 0.04,
#     'delta_Pl': -0.01,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 86,
#     'start_time': 1751295980,
#     'end_time': 1751297060,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 86, 'arrival_speed': 1024.963}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 86,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 86,
#    'arrival_speed': 1024.963,
#    'velocityEvent': {'cycle_id': 86, 'arrival_speed': 1024.963},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 86,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 86,
#     'start_time': 1751295980,
#     'end_time': 1751297060,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 87,
#    'delta_Pt': -61.51,
#    'delta_Cp': -0.09,
#    'delta_Pl': 0.0,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 87,
#    'start_time': 1751297180,
#    'end_time': 1751298380,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 87, 'arrival_speed': 1082.344}},
#  {'GasVolumeProducedEvent': {'cycle_id': 87,
#    'gas_volume': 158.474,
#    'CycleDurationEvent': {'cycle_id': 87,
#     'start_time': 1751297180,
#     'end_time': 1751298380,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 87,
#    'basicPressureEvent': {'cycle_id': 87,
#     'delta_Pt': -61.51,
#     'delta_Cp': -0.09,
#     'delta_Pl': 0.0,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 87,
#     'start_time': 1751297180,
#     'end_time': 1751298380,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 87, 'arrival_speed': 1082.344}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 87,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 87,
#    'arrival_speed': 1082.344,
#    'velocityEvent': {'cycle_id': 87, 'arrival_speed': 1082.344},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 87,
#    'total_duration': 1200,
#    'flow_duration': 840,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 87,
#     'start_time': 1751297180,
#     'end_time': 1751298380,
#     'total_duration': 1200,
#     'flow_duration': 840,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 88,
#    'delta_Pt': 21.44,
#    'delta_Cp': -1.06,
#    'delta_Pl': -0.02,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 88,
#    'start_time': 1751298500,
#    'end_time': 1751299700,
#    'total_duration': 1200,
#    'flow_duration': 720,
#    'shutin_duration': 360}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 88, 'arrival_speed': 960.934}},
#  {'GasVolumeProducedEvent': {'cycle_id': 88,
#    'gas_volume': 142.613,
#    'CycleDurationEvent': {'cycle_id': 88,
#     'start_time': 1751298500,
#     'end_time': 1751299700,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360}}},
#  {'CycleDataEvent': {'cycle_id': 88,
#    'basicPressureEvent': {'cycle_id': 88,
#     'delta_Pt': 21.44,
#     'delta_Cp': -1.06,
#     'delta_Pl': -0.02,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 88,
#     'start_time': 1751298500,
#     'end_time': 1751299700,
#     'total_duration': 1200,
#     'flow_duration': 720,
#     'shutin_duration': 360},
#    'velocityEvent': {'cycle_id': 88, 'arrival_speed': 960.934}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 88,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 88,
#    'arrival_speed': 960.934,
#    'velocityEvent': {'cycle_id': 88, 'arrival_speed': 960.934},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  None,
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 89,
#    'delta_Pt': -88.31,
#    'delta_Cp': -0.97,
#    'delta_Pl': -0.02,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 89,
#    'start_time': 1751299820,
#    'end_time': 1751300900,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 89, 'arrival_speed': 1161.23}},
#  {'GasVolumeProducedEvent': {'cycle_id': 89,
#    'gas_volume': 136.449,
#    'CycleDurationEvent': {'cycle_id': 89,
#     'start_time': 1751299820,
#     'end_time': 1751300900,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 89,
#    'basicPressureEvent': {'cycle_id': 89,
#     'delta_Pt': -88.31,
#     'delta_Cp': -0.97,
#     'delta_Pl': -0.02,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 89,
#     'start_time': 1751299820,
#     'end_time': 1751300900,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 89, 'arrival_speed': 1161.23}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 89,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 89,
#    'arrival_speed': 1161.23,
#    'velocityEvent': {'cycle_id': 89, 'arrival_speed': 1161.23},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 89,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 89,
#     'start_time': 1751299820,
#     'end_time': 1751300900,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  None,
#  {'BasicPressureEvent': {'cycle_id': 90,
#    'delta_Pt': -81.4,
#    'delta_Cp': 0.49,
#    'delta_Pl': 0.0,
#    'ph': 259.8}},
#  {'CycleDurationEvent': {'cycle_id': 90,
#    'start_time': 1751301020,
#    'end_time': 1751302100,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240}},
#  {'PlungerArrivalVelocityEvent': {'cycle_id': 90, 'arrival_speed': 1034.49}},
#  {'GasVolumeProducedEvent': {'cycle_id': 90,
#    'gas_volume': 145.318,
#    'CycleDurationEvent': {'cycle_id': 90,
#     'start_time': 1751301020,
#     'end_time': 1751302100,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240}}},
#  {'CycleDataEvent': {'cycle_id': 90,
#    'basicPressureEvent': {'cycle_id': 90,
#     'delta_Pt': -81.4,
#     'delta_Cp': 0.49,
#     'delta_Pl': 0.0,
#     'ph': 259.8},
#    'cycleDurationEvent': {'cycle_id': 90,
#     'start_time': 1751301020,
#     'end_time': 1751302100,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'velocityEvent': {'cycle_id': 90, 'arrival_speed': 1034.49}}},
#  None,
#  {'PlungerArrivalStatusEvent': {'cycle_id': 90,
#    'non_arrival': False,
#    'unexpected_casing_pressure': False,
#    'UnexpectedLowCasingPressure': None,
#    'description': 'Plunger arrived; Casing pressure normal.'}},
#  {'PlungerUnsafeVelocity': {'cycle_id': 90,
#    'arrival_speed': 1034.49,
#    'velocityEvent': {'cycle_id': 90, 'arrival_speed': 1034.49},
#    'description': 'The PlungerUnsafeVelocity event is triggered when the velocity of the plunger upon arrival at the surface exceeds a predefined safety threshold. This indicates potentially dangerous impact forces that could damage equipment or signal aggressive flow conditions. Operators should consider adjusting flow duration, shut-in pressure, or inspect for mechanical wear.',
#    'safety_threshold': 2.5}},
#  {'UnexpectedLowCycleDuration': {'cycle_id': 90,
#    'total_duration': 1080,
#    'flow_duration': 720,
#    'shutin_duration': 240,
#    'thresholds': {'total_duration': 600,
#     'flow_duration': 300,
#     'shutin_duration': 300},
#    'CycleDurationEvent': {'cycle_id': 90,
#     'start_time': 1751301020,
#     'end_time': 1751302100,
#     'total_duration': 1080,
#     'flow_duration': 720,
#     'shutin_duration': 240},
#    'description': 'The UnexpectedLowCycleDuration event flags abnormally short cycles, either in total duration or during specific segments like flow or shut-in. Such a condition could suggest premature venting, shallow slug formation, or mistimed plunger launches. Identifying low-duration anomalies is important to optimize cycle timing and avoid inefficient runtimes.'}},
#  None,
#  ...]
